# %%
import pandas as pd 

# read the datasets 
df1 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2000.csv") 
df2 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2001.csv")  
df3 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2002.csv") 
df4 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2003.csv") 
df5 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2004.csv") 
df6 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2005.csv")  
df7 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2006.csv")  
df8 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2007.csv")  
df9 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2008.csv") 
df10 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2009.csv") 
df11 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2010.csv")  
df12 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2011.csv") 
df13 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2012.csv")  
df14 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2013.csv")  
df15 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2014.csv")  
df16 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2015.csv")  
df17 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2016.csv")  
df18 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2017.csv") 
df19 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2018_2019.csv") 
df20 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2020_2021.csv") 
df21 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2022_2023.csv") 
df22 = pd.read_csv("C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/2024.csv") 

# print the datasets 
print(df1.head()) 
print(df2.head())
# Out:
#                      name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Wolverhampton, England  2000-01-01     46.6     33.6  40.7          44.5
# 1  Wolverhampton, England  2000-01-02     50.8     39.3  44.3          50.8
# 2  Wolverhampton, England  2000-01-03     50.9     38.5  45.9          50.9
# 3  Wolverhampton, England  2000-01-04     42.4     34.1  37.4          35.9
# 4  Wolverhampton, England  2000-01-05     52.1     35.1  43.5          52.1
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          33.6       39.8  39.4      95.1  ...          NaN      NaN
# 1          35.0       40.8  41.2      89.1  ...          NaN      NaN
# 2          34.2       42.4  42.5      88.2  ...          NaN      NaN
# 3          27.5       31.6  34.3      88.6  ...          NaN      NaN
# 4          28.5       37.9  39.1      84.5  ...          NaN      NaN
#
#    severerisk              sunrise               sunset  moonphase  \
# ...

# %%
concat_data = pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,
                         df14,df15,df16,df17,df18,df19,df20,df21,df22,], ignore_index=True) 
print(concat_data)
# Out:
#                         name    datetime  tempmax  tempmin  temp  \
# 0     Wolverhampton, England  2000-01-01     46.6     33.6  40.7
# 1     Wolverhampton, England  2000-01-02     50.8     39.3  44.3
# 2     Wolverhampton, England  2000-01-03     50.9     38.5  45.9
# 3     Wolverhampton, England  2000-01-04     42.4     34.1  37.4
# 4     Wolverhampton, England  2000-01-05     52.1     35.1  43.5
# ...                      ...         ...      ...      ...   ...
# 8838  Wolverhampton, England  2024-04-12     63.8     49.0  56.0
# 8839  Wolverhampton, England  2024-04-13     59.0     47.5  53.0
# 8840  Wolverhampton, England  2024-04-14     54.2     40.4  48.0
# 8841  Wolverhampton, England  2024-04-15     48.8     44.3  46.2
# 8842  Wolverhampton, England  2024-04-16     53.0     40.8  47.1
#
#       feelslikemax  feelslikemin  feelslike   dew  humidity  ...  solarenergy  \
# 0             44.5          33.6       39.8  39.4      95.1  ...          NaN
# ...

# %%
# Save to CSV file
concat_data.to_csv('weatherdata.csv', index=False)

# %%
concat_data.to_csv('C:/Users/Uche Buzz/Desktop/School stuff/Final Project/Datasets/weatherdata.csv', index=False)

# %%
concat_data.head()
# Out:
#                      name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Wolverhampton, England  2000-01-01     46.6     33.6  40.7          44.5
# 1  Wolverhampton, England  2000-01-02     50.8     39.3  44.3          50.8
# 2  Wolverhampton, England  2000-01-03     50.9     38.5  45.9          50.9
# 3  Wolverhampton, England  2000-01-04     42.4     34.1  37.4          35.9
# 4  Wolverhampton, England  2000-01-05     52.1     35.1  43.5          52.1
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          33.6       39.8  39.4      95.1  ...          NaN      NaN
# 1          35.0       40.8  41.2      89.1  ...          NaN      NaN
# 2          34.2       42.4  42.5      88.2  ...          NaN      NaN
# 3          27.5       31.6  34.3      88.6  ...          NaN      NaN
# 4          28.5       37.9  39.1      84.5  ...          NaN      NaN
#
#    severerisk              sunrise               sunset  moonphase  \
# ...
